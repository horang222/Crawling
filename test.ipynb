# %%
import pandas as pd

fmkorea = pd.read_csv('./csv/fmkorea.csv')
fmkorea.head(10)
# Out:
#                                            제목            카테고리
# 0   폐비닐에서 기름을 뽑아낸 한국 기사를 본 미국인들의 반응.JPG  [28]              유머  \
# 1              PD 인생 최대의 위기 ㄷㄷㄷㄷ....JPG  [62]              유머
# 2                    로마사람들이 콜로세움에 갔던 이유  [42]              유머
# 3                 2004년 논산훈련소 수류탄 자살사건  [158]  미스터리 - 미스터리/공포
# 4                ㅇㅎ) 올 여름을 강타할 호러영화.gif  [58]         유머 - 움짤
# 5                        무림 고수들의 대결.jpg  [41]              유머
# 6                  노트북 청소하는 꿀팁.....gif  [112]         유머 - 움짤
# 7              문신 있는 여자가 할 수 있는 직업.jpg  [231]              유머
# 8  스포 | 마블 가오갤 3 OST 끝내주는 노래들 삽입 장면들 설명  [94]   영화/TV - 정보/기사
# 9    [인천vs수원] 이기제 "어린이날 골로 자녀에게 큰 선물했다"  [19]  국내축구 - 경기사진/영상
#
#                                         링크
# 0  https://www.fmkorea.com/best/5741387855
# 1  https://www.fmkorea.com/best/5741404782
# 2  https://www.fmkorea.com/best/5739890499
# 3  https://www.fmkorea.com/best/5740447895
# 4  https://www.fmkorea.com/best/5741368784
# 5  https://www.fmkorea.com/best/5740241376
# 6  https://www.fmkorea.com/best/5739779268
# 7  https://www.fmkorea.com/best/5740196004
# 8  https://www.fmkorea.com/best/5740820486
# 9  https://www.fmkorea.com/best/5740921470

# %%
fmkorea.shape
# Out:
# (200, 3)

# %%
good = fmkorea.loc[fmkorea['제목'].str.contains('ㅇㅎ')]
display(good)
# Out:
#                              제목     카테고리
# 4  ㅇㅎ) 올 여름을 강타할 호러영화.gif  [58]  유머 - 움짤  \
#
#                                         링크
# 4  https://www.fmkorea.com/best/5741368784

# %%
comics = fmkorea.loc[fmkorea['제목'].str.contains('수원')]
display(comics)
# Out:
#                                                     제목            카테고리
# 9             [인천vs수원] 이기제 "어린이날 골로 자녀에게 큰 선물했다"  [19]  국내축구 - 경기사진/영상  \
# 10       [인천vs수원] 에르난데스 대포알 중거리 양형모 선방 ㄷㄷㄷㄷㄷㄷㄷㄷㄷ  [16]  국내축구 - 경기사진/영상
# 37    [k1.told] 수원의 '첫 승'...최성용 대행이 이뤄낸 '마지막 약속'  [23]    국내축구 - 정보/기사
# 84                           수원 승리 게시물에 댓글 단 박재정  [48]     국내축구 - K리그1
# 92            수원삼성 최성용 "소식 들었을 이병근 감독님, 보고 싶습니다"  [35]    국내축구 - 정보/기사
# 108                                   지금 신난 수원팬들  [67]     국내축구 - K리그1
# 115             "마음을 좀 덜었네요" 첫 승 수원 최성용 감독대행의 눈물  [41]    국내축구 - 정보/기사
# 128              [인천vs수원] 청백적 우산 돌리는 수원 원정팬들 ㅋㅋㅋ  [51]  국내축구 - 경기사진/영상
# 130  [인천vs수원] '드디어 첫승' 힘들었을 선수들, 코칭스태프, 팬들까지 ㅠ...  ...  국내축구 - 경기사진/영상
# 134                    [오피셜] 수원삼성 울산 측면수비 이기제 영입  [51]     국내축구 - K리그1
# 137   [인천vs수원] 으아아 권한진 슈팅 양형모 슈퍼세이브 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ  [23]  국내축구 - 경기사진/영상
# 147  [인천vs수원] 0:1 경기종료! 11라운드만에 드디어 리그 첫승 기록하는 ... ...  국내축구 - 경기사진/영상
# 157                       [인천vs수원] 생각이 많아보이는 병버지  [24]  국내축구 - 경기사진/영상
# 189         [인천vs수원] 김보섭 터닝슛 양형모 스치고 골대 ㄷㄷㄷㄷㄷㄷㄷㄷㄷ  [9]  국내축구 - 경기사진/영상
#
#                                           링크
# 9    https://www.fmkorea.com/best/5740921470
# 10   https://www.fmkorea.com/best/5740806200
# 37   https://www.fmkorea.com/best/5740945768
# 84   https://www.fmkorea.com/best/5741048161
# 92   https://www.fmkorea.com/best/5741015699
# 108  https://www.fmkorea.com/best/5740826610
# 115  https://www.fmkorea.com/best/5740963054
# 128  https://www.fmkorea.com/best/5740827172
# 130  https://www.fmkorea.com/best/5740904435
# 134  https://www.fmkorea.com/best/5740912194
# 137  https://www.fmkorea.com/best/5740859176
# 147  https://www.fmkorea.com/best/5740897840
# 157  https://www.fmkorea.com/best/5740784544
# 189  https://www.fmkorea.com/best/5740662633

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import pandas as pd

# 크롬 드라이버 자동 업데이트
from webdriver_manager.chrome import ChromeDriverManager # webdriver_manager 처음 실행할 때는 다운받느라 조금 시간이 걸릴 수 있음

# 브라우저 꺼짐 방지
options = Options()
options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 없애기
options.add_experimental_option('excludeSwitches', ['enable-logging'])

service = Service(executable_path=ChromeDriverManager().install())

# %%
info_list = infos[0].text.split('/')
info_list
# Out:
# ['쇼핑몰: 나이키 ', ' 가격: 20%할인 ', ' 배송: 무료']

# %%
mall = info_list[0].split(':')[-1].strip()
mall
# Out:
# '나이키'

# %%
price = info_list[1].split(':')[-1].strip()
# price = f'{price}원'
price
# Out:
# '20%할인'

# %%
delivery = info_list[2].split(':')[-1].strip()
delivery
# Out:
# '무료'

# %%
titles = [tit.text.strip() for tit in tits]
links = [link.get_attribute('href') for link in tits]
titles
# links
# Out:
# ['나이키의류',
#  '크라운 산도 딸기크림치즈 161g x 12개 외  [4]',
#  'AIRism 빤쓰  [102]',
#  '삼양라면 20봉 x 2박스  [12]',
#  '얇은피 만두 고기2 김치2  [67]',
#  'Skt망/161기가+일2기가+소진시 3mps 무제/통화,문자 무제한  [43]',
#  '(타임딜 예고) (5.6 1시) 삼성 식기세척기 DW60A5055FS  [30]',
#  '알로하 수제파이 타르트 2가지맛 골라담기 5개 + 5개  [18]',
#  'AOC 27인치 QHD 모니터 Q27G2SD  [30]',
#  '삼성 32인치 4K 퀀텀닷 IPS 모니터 S32B800  [19]',
#  '아이패드 프로 11 4세대 M2 WIFI 128GB  [24]',
#  '시세이도 헤어키친 커스터마이징 샴푸&트리트먼트&에센스 체험세트  [17]',
#  '풀무원 39주년 할인 + 페이코 18퍼 할인  [132]',
#  '[빅스예고] 로보락S8 Pro Ultra  [223]',
#  '가민 포러너 265  [156]',
#  '언더아머 바람막이 자켓  [190]',
#  '삼성전자 무한 잉크젯 복합기 잉크포함 SL-T2170W  [31]',
#  '레이저 스트림 컨트롤러  [28]']

# %%
data = []
for tit, info_list in zip(tits, infos):
    record = []
    title = tit.text.strip()
    link = tit.get_attribute('href')
    record += [title, link]

    info_list = info_list.text.split('/')
    
    mall = info_list[0].split(':')[-1].strip()
    price = info_list[1].split(':')[-1].strip()
    delivery = info_list[2].split(':')[-1].strip()

    product_info = [mall, price, delivery]
    record += product_info
    data.append(record)

data
# Out:
# [['나이키의류', 'https://www.fmkorea.com/5741683142', '나이키', '20%할인', '무료'],
#  ['크라운 산도 딸기크림치즈 161g x 12개 외  [4]',
#   'https://www.fmkorea.com/5741680597',
#   '쿠팡',
#   '17,040원',
#   '와우무료'],
#  ['AIRism 빤쓰  [102]',
#   'https://www.fmkorea.com/5741546322',
#   '유니클로',
#   '12,900원',
#   '30,000만이상무'],
#  ['삼양라면 20봉 x 2박스  [12]',
#   'https://www.fmkorea.com/5741483999',
#   '지마켓',
#   '스클20,250',
#   '스클무료'],
#  ['얇은피 만두 고기2 김치2  [67]',
#   'https://www.fmkorea.com/5741457143',
#   '풀무원',
#   '4,994원',
#   '3,000원'],
#  ['Skt망/161기가+일2기가+소진시 3mps 무제/통화,문자 무제한  [43]',
#   'https://www.fmkorea.com/5741435317',
#   '아이즈모바일',
#   '0원',
#   '유심비4,400'],
#  ['(타임딜 예고) (5.6 1시) 삼성 식기세척기 DW60A5055FS  [30]',
#   'https://www.fmkorea.com/5741338636',
#   '11번가',
#   '399,000원',
#   '무료'],
#  ['알로하 수제파이 타르트 2가지맛 골라담기 5개 + 5개  [18]',
#   'https://www.fmkorea.com/5741350616',
#   '네이버원쁠딜',
#   '18,490원',
#   '0원'],
#  ['AOC 27인치 QHD 모니터 Q27G2SD  [30]',
#   'https://www.fmkorea.com/5741345641',
#   '11번가',
#   '361,080원',
#   '무료'],
#  ['삼성 32인치 4K 퀀텀닷 IPS 모니터 S32B800  [19]',
#   'https://www.fmkorea.com/5741311149',
#   '옥션',
#   '569,110원',
#   '무료'],
#  ['아이패드 프로 11 4세대 M2 WIFI 128GB  [24]',
#   'https://www.fmkorea.com/5741326681',
#   '11번가',
#   '1,022,750원',
#   '무료'],
#  ['시세이도 헤어키친 커스터마이징 샴푸&트리트먼트&에센스 체험세트  [17]',
#   'https://www.fmkorea.com/5741314768',
#   '네이버스토어',
#   '0원',
#   '2,500원'],
#  ['풀무원 39주년 할인 + 페이코 18퍼 할인  [132]',
#   'https://www.fmkorea.com/5741176819',
#   '풀무원',
#   '매상품다름',
#   '4만원이상시무료'],
#  ['[빅스예고] 로보락S8 Pro Ultra  [223]',
#   'https://www.fmkorea.com/5741004982',
#   'G마켓',
#   '1,490,000원',
#   '무료'],
#  ['가민 포러너 265  [156]',
#   'https://www.fmkorea.com/5740787990',
#   '하이마트',
#   '525,990원',
#   '무료'],
#  ['언더아머 바람막이 자켓  [190]',
#   'https://www.fmkorea.com/5740718370',
#   '11번가',
#   '35,910원',
#   '무료'],
#  ['삼성전자 무한 잉크젯 복합기 잉크포함 SL-T2170W  [31]',
#   'https://www.fmkorea.com/5740507774',
#   '11번가',
#   '167,160원',
#   '무료'],
#  ['레이저 스트림 컨트롤러  [28]',
#   'https://www.fmkorea.com/5740454390',
#   '쿠팡',
#   '989,010원',
#   '무료']]

# %%
driver = webdriver.Chrome(service=service, options=options)

data = []

for page_no in range(1, 6):
    url = f'https://www.fmkorea.com/index.php?mid=hotdeal&page={page_no}'
    driver.get(url)
    time.sleep(3)

    tits = driver.find_elements(By.CLASS_NAME, 'hotdeal_var8')
    infos = driver.find_elements(By.CLASS_NAME, 'hotdeal_info')

    for tit, info_list in zip(tits, infos):
        record = []
        title = tit.text.strip()
        link = tit.get_attribute('href')
        record += [title]

        info_list = info_list.text.split('/')
        
        mall = info_list[0].split(':')[-1].strip()
        price = info_list[1].split(':')[-1].strip()
        delivery = info_list[2].split(':')[-1].strip()

        product_info = [mall, price, delivery, link]
        record += product_info
        data.append(record)

driver.quit()

cols = ['글 제목', '쇼핑몰', '가격', '배송비', '링크']
df = pd.DataFrame(data, columns=cols)
print('데이터프레임 생성 완료!!!')
# Out:
# 데이터프레임 생성 완료!!!

# %%
df.shape
# Out:
# (85, 5)

# %%
df.head(10)
# Out:
#                                 글 제목    쇼핑몰          가격   배송비
# 0      짱구 피규어 차량용 방향제 디퓨져 2종 1택  [1]   11번가     9,900원~    무료  \
# 1            덴마크 구워먹는 모짜렐라치즈 400gx2팩    G마켓   스클15,050원    무료
# 2                        Cgv 1매  [2]  신한플레이      9,500원    무료
# 3     도브 데오 알로에 50ml 2개 6,550원  [19]   11번가      6,550원    무배
# 4   백종원의 제주 돼지 부대찌개 밀키트 2개 4인분  [12]    지마켓     25,110원    무료
# 5    삼성전자 갤럭시 S23 울트라 512G 자급제  [17]   11번가  1,327,950원    무료
# 6                    Cgv 영화예매권  [22]     옥션     10,200원    무료
# 7  국희 땅콩샌드 70g x 3개 가성비대용량도 있음  [44]     쿠팡      1,900원  와우무료
# 8      마니커에프앤지 통살치킨너겟 300g x 4봉  [8]     톡딜     11,900원    무료
# 9                         나이키의류  [4]    나이키       20%할인    무료
#
#                                    링크
# 0  https://www.fmkorea.com/5741850495
# 1  https://www.fmkorea.com/5741846965
# 2  https://www.fmkorea.com/5741842792
# 3  https://www.fmkorea.com/5741801254
# 4  https://www.fmkorea.com/5741791531
# 5  https://www.fmkorea.com/5741778111
# 6  https://www.fmkorea.com/5741768658
# 7  https://www.fmkorea.com/5741711207
# 8  https://www.fmkorea.com/5741695723
# 9  https://www.fmkorea.com/5741683142

# %%
df.to_csv('./hotdeal.csv',encoding='utf-8', index=False)
print('데이터프레임 저장 완료!!!')

# %%
hotdeal = pd.read_csv('./csv/hotdeal.csv')
display(hotdeal.head(10))
# Out:
#                                 글 제목   쇼핑몰          가격         배송비
# 0      도브 데오 알로에 50ml 2개 6,550원  [3]  11번가      6,550원          무배  \
# 1    백종원의 제주 돼지 부대찌개 밀키트 2개 4인분  [8]   지마켓     25,110원          무료
# 2    삼성전자 갤럭시 S23 울트라 512G 자급제  [12]  11번가  1,327,950원          무료
# 3                    Cgv 영화예매권  [16]    옥션     10,200원          무료
# 4  국희 땅콩샌드 70g x 3개 가성비대용량도 있음  [43]    쿠팡      1,900원        와우무료
# 5      마니커에프앤지 통살치킨너겟 300g x 4봉  [7]    톡딜     11,900원          무료
# 6                         나이키의류  [3]   나이키       20%할인          무료
# 7    크라운 산도 딸기크림치즈 161g x 12개 외  [9]    쿠팡     17,040원        와우무료
# 8                   AIRism 빤쓰  [131]  유니클로     12,900원  30,000만이상무
# 9               삼양라면 20봉 x 2박스  [17]   지마켓    스클20,250        스클무료
#
#                                    링크
# 0  https://www.fmkorea.com/5741801254
# 1  https://www.fmkorea.com/5741791531
# 2  https://www.fmkorea.com/5741778111
# 3  https://www.fmkorea.com/5741768658
# 4  https://www.fmkorea.com/5741711207
# 5  https://www.fmkorea.com/5741695723
# 6  https://www.fmkorea.com/5741683142
# 7  https://www.fmkorea.com/5741680597
# 8  https://www.fmkorea.com/5741546322
# 9  https://www.fmkorea.com/5741483999

# %%
coupang = hotdeal.loc[hotdeal['쇼핑몰'] == '쿠팡', ['글 제목', '가격']]
display(coupang)
# Out:
#                                              글 제목        가격
# 4               국희 땅콩샌드 70g x 3개 가성비대용량도 있음  [43]    1,900원
# 7                 크라운 산도 딸기크림치즈 161g x 12개 외  [9]   17,040원
# 23                              멘소래담 스프레이3종  [22]  989,010원
# 40                    1+1 블루안트 2X밴드 쿨토시 일반형  [16]   15,270원
# 55  필립스 SkinIQ 9000 시리즈 전기면도기 S9985/50 와우기준  [13]  240,110원
# 63                             매일두유 고단백 54팩  [35]    8,760원
# 84                             칸쵸 54g X 32개  [18]   20,700원
# 89  풀무원 NEW얇은피 만두 고기4봉+김치2봉+꺳잎2봉+떙초2봉 총 10봉  [16]   35,970원

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd
import time


# 크롬 드라이버 자동 업데이트
from webdriver_manager.chrome import ChromeDriverManager # webdriver_manager 처음 실행할 때는 다운받느라 조금 시간이 걸릴 수 있음

# 브라우저 꺼짐 방지
options = Options()
options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 없애기
options.add_experimental_option('excludeSwitches', ['enable-logging'])

service = Service(executable_path=ChromeDriverManager().install())
